# %%
library(Seurat)
ref = readRDS('scRNAseq_longitudinal_LCMV_Arm_Cl13.Rds')

# %%
ref = subset(ref, cells = colnames(ref)[ref$ClusterNames %in% c('Exh-Int', 'Exh-KLR', 'Exh-Pre', 'Exh-Prog', 'Exh-Term'
                                                                #,'Exh-HSP', 'Exh-TermGzma'
                                                                , 'ISG') & ref$sampleID %in% c('Cl13_d8', 'Cl13_d15', 'Cl13_d30')])

# %%
Idents(ref) = 'ClusterNames'
a = FindAllMarkers(ref, only.pos = TRUE)
# Out:
# Calculating cluster Exh-Pre
#
# Calculating cluster Exh-Int
#
# Calculating cluster ISG
#
# Calculating cluster Exh-KLR
#
# Calculating cluster Exh-Term
#
# Calculating cluster Exh-Prog

# %%
table(ref$ClusterNames)
# Out:
#  Exh-Int  Exh-KLR  Exh-Pre Exh-Prog Exh-Term      ISG
#     2697      610      942      968     1361      210

# %%
a['Rack1',]
# Out:
#       p_val         avg_log2FC pct.1 pct.2 p_val_adj
# Rack1 1.146625e-156 0.6216553  1     1     1.671436e-152

# %%
a[a$avg_log2FC > 0,][1:60,]
# Out:
#               p_val         avg_log2FC pct.1 pct.2 p_val_adj
# Rack1         1.146625e-156 0.6216553  1.000 1.000 1.671436e-152
# Eef2          4.352068e-138 0.6892725  1.000 1.000 6.344009e-134
# Rbm3          3.290913e-134 0.7659152  0.999 0.998 4.797164e-130
# Gapdh         2.981350e-131 0.7474791  1.000 0.999 4.345914e-127
# Eef1b2        4.966268e-131 0.6356231  0.999 1.000 7.239329e-127
# Coro1a        2.351275e-126 0.6775762  1.000 1.000 3.427454e-122
# Eif3h         7.179731e-118 0.6446240  0.997 0.988 1.046589e-113
# Lgals1        4.511016e-101 1.0124826  0.983 0.842  6.575708e-97
# Naca           3.497746e-97 0.4787059  1.000 1.000  5.098664e-93
# Actg1          9.084342e-93 0.7925209  1.000 0.999  1.324225e-88
# Cox4i1         5.338552e-90 0.5242337  0.997 0.983  7.782008e-86
# Eef1a1         1.828868e-88 0.4093573  1.000 1.000  2.665941e-84
# Btf3           2.498961e-85 0.4595445  0.998 1.000  3.642736e-81
# ...

# %%
a = FindMarkers(ref, c('Exh-Pre'), 'Exh-Prog')
head(a, 60)
# Out:
#           p_val         avg_log2FC pct.1 pct.2 p_val_adj
# Rack1     1.146625e-156  0.6216553 1.000 1.000 1.671436e-152
# Ddx5      3.695143e-155 -0.7953631 0.997 1.000 5.386410e-151
# Ccl5      1.128613e-139 -2.0948166 0.485 0.949 1.645179e-135
# Eef2      4.352068e-138  0.6892725 1.000 1.000 6.344009e-134
# Rbm3      3.290913e-134  0.7659152 0.999 0.998 4.797164e-130
# Gapdh     2.981350e-131  0.7474791 1.000 0.999 4.345914e-127
# Eef1b2    4.966268e-131  0.6356231 0.999 1.000 7.239329e-127
# Dusp1     2.104940e-126 -1.2726050 0.794 0.970 3.068371e-122
# Coro1a    2.351275e-126  0.6775762 1.000 1.000 3.427454e-122
# Eif3h     7.179731e-118  0.6446240 0.997 0.988 1.046589e-113
# Btg1      2.159791e-107 -0.8076834 0.975 0.997 3.148328e-103
# Lgals1    4.511016e-101  1.0124826 0.983 0.842  6.575708e-97
# Naca       3.497746e-97  0.4787059 1.000 1.000  5.098664e-93
# Eif4a2     1.148735e-94 -0.8045034 0.620 0.906  1.674511e-90
# ...

# %%
saveRDS(a, 'giles_clusters.RDS')
